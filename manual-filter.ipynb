# %%
import cv2
import sys
import numpy as np

def nothing(x):
    pass

cv2.namedWindow('image')

cv2.createTrackbar('HMin','image',0,179,nothing) 
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

cv2.setTrackbarPos('HMin', 'image', 87)
cv2.setTrackbarPos('SMin', 'image', 55)
cv2.setTrackbarPos('VMin', 'image', 35)

hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0



img = cv2.imread('image-train.jpg')
output = img
waitTime = 33

while(1):


    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(img,img, mask= mask)


    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    
    cv2.imshow('image',output)

    
    if cv2.waitKey(waitTime) & 0xFF == ord('q'):
        break
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# libGL error: MESA-LOADER: failed to open radeonsi: /home/teenarp2003/miniconda3/envs/opencv/lib/python3.9/site-packages/zmq/backend/cython/../../../../.././libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /usr/lib/dri/radeonsi_dri.so) (search paths /usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: radeonsi
# libGL error: MESA-LOADER: failed to open radeonsi: /home/teenarp2003/miniconda3/envs/opencv/lib/python3.9/site-packages/zmq/backend/cython/../../../../.././libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /usr/lib/dri/radeonsi_dri.so) (search paths /usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: radeonsi
# libGL error: MESA-LOADER: failed to open swrast: /home/teenarp2003/miniconda3/envs/opencv/lib/python3.9/site-packages/zmq/backend/cython/../../../../.././libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /usr/lib/dri/swrast_dri.so) (search paths /usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: swrast
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2
# (hMin = 87 , sMin = 55, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 112), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 121), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 157), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 179), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 199), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 222), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 238), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 255), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 238), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 220), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 193), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 171), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 160), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 157), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 137), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 141), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 162), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 168), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 170), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 176), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 191), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 205), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 217), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 220), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 221), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 218), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 203), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 182), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 167), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 151), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 127), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 86), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 21), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 21), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 24), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 26), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 55, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 56, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 59, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 72, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 114, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 159, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 188, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 200, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 201, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 180, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 118, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 68, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 22, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 17, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 31, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 84, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 134, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 149, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 144, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 86, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 33, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 26, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 36, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 62, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 91, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 120, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 133, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 134, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 132, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 107, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 77, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 57, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 52, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 99 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 121 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 101 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 113 , sMin = 51, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
